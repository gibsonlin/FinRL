# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/1-Introduction/Stock_NeurIPS2018_SB3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading
#
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Task Description](#0)
# * [2. Install Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. A List of Python Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download and Preprocess Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5. Build Market Environment in OpenAI Gym-style](#4)
#     * [5.1. Data Split](#4.1)
#     * [5.3. Environment for Training](#4.2)
# * [6. Train DRL Agents](#5)
# * [7. Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Task Discription

# %% [markdown]
# We train a DRL agent for stock trading. This task is modeled as a Markov Decision Process (MDP), and the objective function is maximizing (expected) cumulative return.
#
# We specify the state-action-reward as follows:
#
# * **State s**: The state space represents an agent's perception of the market environment. Just like a human trader analyzing various information, here our agent passively observes many features and learns by interacting with the market environment (usually by replaying historical data).
#
# * **Action a**: The action space includes allowed actions that an agent can take at each state. For example, a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying. When an action operates multiple shares, a ∈{−k, ..., −1, 0, 1, ..., k}, e.g.. "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * **Reward function r(s, a, s′)**: Reward is an incentive for an agent to learn a better policy. For example, it can be the change of the portfolio value when taking a at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio values at state s′ and s, respectively
#
#
# **Market environment**: 30 consituent stocks of Dow Jones Industrial Average (DJIA) index. Accessed at the starting date of the testing period.
#
#
# The data for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Install Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install packages

# %%
## install required packages
# !pip install swig
# !pip install wrds
# !pip install pyportfolioopt
## install finrl library
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git
# Out:
# Requirement already satisfied: swig in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (4.1.1)
# Requirement already satisfied: wrds in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (3.1.6)
# Requirement already satisfied: sqlalchemy<2 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from wrds) (1.4.47)
# Requirement already satisfied: pandas in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from wrds) (1.5.3)
# Requirement already satisfied: psycopg2-binary in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from wrds) (2.9.5)
# Requirement already satisfied: numpy in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from wrds) (1.24.2)
# Requirement already satisfied: scipy in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from wrds) (1.10.1)
# Requirement already satisfied: greenlet!=0.4.17 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from sqlalchemy<2->wrds) (2.0.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from pandas->wrds) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from pandas->wrds) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas->wrds) (1.16.0)
# Requirement already satisfied: pyportfolioopt in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (1.5.4)
# Requirement already satisfied: cvxpy<2.0.0,>=1.1.10 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from pyportfolioopt) (1.3.1)
# Requirement already satisfied: scipy<2.0,>=1.3 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from pyportfolioopt) (1.10.1)
# Requirement already satisfied: numpy<2.0.0,>=1.22.4 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from pyportfolioopt) (1.24.2)
# Requirement already satisfied: pandas>=0.19 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from pyportfolioopt) (1.5.3)
# Requirement already satisfied: osqp>=0.4.1 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from cvxpy<2.0.0,>=1.1.10->pyportfolioopt) (0.6.2.post8)
# Requirement already satisfied: setuptools>65.5.1 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from cvxpy<2.0.0,>=1.1.10->pyportfolioopt) (65.6.3)
# Requirement already satisfied: scs>=1.1.6 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from cvxpy<2.0.0,>=1.1.10->pyportfolioopt) (3.2.2)
# Requirement already satisfied: ecos>=2 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from cvxpy<2.0.0,>=1.1.10->pyportfolioopt) (2.0.12)
# Requirement already satisfied: pytz>=2020.1 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from pandas>=0.19->pyportfolioopt) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from pandas>=0.19->pyportfolioopt) (2.8.2)
# Requirement already satisfied: qdldl in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from osqp>=0.4.1->cvxpy<2.0.0,>=1.1.10->pyportfolioopt) (0.1.5.post3)
# Requirement already satisfied: six>=1.5 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas>=0.19->pyportfolioopt) (1.16.0)
# Collecting git+https://github.com/AI4Finance-Foundation/FinRL.git
#   Cloning https://github.com/AI4Finance-Foundation/FinRL.git to /tmp/pip-req-build-3qii8qnj
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/FinRL.git /tmp/pip-req-build-3qii8qnj
#   Resolved https://github.com/AI4Finance-Foundation/FinRL.git to commit d3e35c7d94da2b0b4f44734a226de360b5c09d52
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2
#   Cloning https://github.com/quantopian/pyfolio.git to /tmp/pip-install-p4wazshk/pyfolio_ed210b86a3924722a442c1b7b4b79bac
#   Running command git clone --filter=blob:none --quiet https://github.com/quantopian/pyfolio.git /tmp/pip-install-p4wazshk/pyfolio_ed210b86a3924722a442c1b7b4b79bac
#   Resolved https://github.com/quantopian/pyfolio.git to commit 4b901f6d73aa02ceb6d04b7d83502e5c6f2e81aa
#   Preparing metadata (setup.py) ... done
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to /tmp/pip-install-p4wazshk/elegantrl_7e168aea3c39417aa5bae2ac813aa622
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git /tmp/pip-install-p4wazshk/elegantrl_7e168aea3c39417aa5bae2ac813aa622
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit 594b0c31de443a24c1032b75418fdc134664e92f
#   Preparing metadata (setup.py) ... done
# Collecting ccxt>=1.66.32
#   Using cached ccxt-3.0.44-py2.py3-none-any.whl (3.6 MB)
# Collecting gputil
#   Using cached GPUtil-1.4.0.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting ray[default,tune]>=2.0.0
#   Using cached ray-2.3.1-cp38-cp38-manylinux2014_x86_64.whl (58.6 MB)
# Collecting jqdatasdk
#   Using cached jqdatasdk-1.8.11-py3-none-any.whl (158 kB)
# Requirement already satisfied: pandas>=1.1.5 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from finrl==0.3.5) (1.5.3)
# Collecting exchange_calendars==3.6.3
#   Using cached exchange_calendars-3.6.3.tar.gz (152 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: wrds>=3.1.6 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from finrl==0.3.5) (3.1.6)
# Collecting matplotlib
#   Using cached matplotlib-3.7.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.2 MB)
# Collecting scikit-learn>=0.21.0
#   Using cached scikit_learn-1.2.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.8 MB)
# Collecting lz4
#   Using cached lz4-4.3.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
# Collecting importlib-metadata==4.13.0
#   Using cached importlib_metadata-4.13.0-py3-none-any.whl (23 kB)
# Collecting stable-baselines3<2.0.0,>=1.6.2
#   Using cached stable_baselines3-1.7.0-py3-none-any.whl (171 kB)
# Collecting alpaca_trade_api>=2.1.0
#   Using cached alpaca_trade_api-3.0.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: numpy>=1.17.3 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from finrl==0.3.5) (1.24.2)
# Collecting stockstats>=0.4.0
#   Using cached stockstats-0.5.2-py2.py3-none-any.whl (20 kB)
# Collecting tensorboardX
#   Using cached tensorboardX-2.6-py2.py3-none-any.whl (114 kB)
# Collecting gym>=0.17
#   Using cached gym-0.26.2.tar.gz (721 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting yfinance
#   Using cached yfinance-0.2.14-py2.py3-none-any.whl (59 kB)
# Collecting pyluach
#   Using cached pyluach-2.2.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: python-dateutil in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from exchange_calendars==3.6.3->finrl==0.3.5) (2.8.2)
# Requirement already satisfied: pytz in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from exchange_calendars==3.6.3->finrl==0.3.5) (2023.3)
# Collecting toolz
#   Using cached toolz-0.12.0-py3-none-any.whl (55 kB)
# Collecting korean_lunar_calendar
#   Using cached korean_lunar_calendar-0.3.1-py3-none-any.whl (9.0 kB)
# Requirement already satisfied: zipp>=0.5 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from importlib-metadata==4.13.0->finrl==0.3.5) (3.15.0)
# Requirement already satisfied: urllib3<2,>1.24 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from alpaca_trade_api>=2.1.0->finrl==0.3.5) (1.26.15)
# Collecting msgpack==1.0.3
#   Using cached msgpack-1.0.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (322 kB)
# Collecting aiohttp==3.8.1
#   Using cached aiohttp-3.8.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.3 MB)
# Collecting PyYAML==6.0
#   Using cached PyYAML-6.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (701 kB)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from alpaca_trade_api>=2.1.0->finrl==0.3.5) (1.5.1)
# Collecting websockets<11,>=9.0
#   Using cached websockets-10.4-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
# Requirement already satisfied: requests<3,>2 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from alpaca_trade_api>=2.1.0->finrl==0.3.5) (2.28.2)
# Collecting deprecation==2.1.0
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting multidict<7.0,>=4.5
#   Using cached multidict-6.0.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (121 kB)
# Collecting yarl<2.0,>=1.0
#   Using cached yarl-1.8.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (262 kB)
# Collecting aiosignal>=1.1.2
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: attrs>=17.3.0 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from aiohttp==3.8.1->alpaca_trade_api>=2.1.0->finrl==0.3.5) (22.2.0)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting frozenlist>=1.1.1
#   Using cached frozenlist-1.3.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (161 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from aiohttp==3.8.1->alpaca_trade_api>=2.1.0->finrl==0.3.5) (2.1.1)
# Requirement already satisfied: packaging in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from deprecation==2.1.0->alpaca_trade_api>=2.1.0->finrl==0.3.5) (23.0)
# Requirement already satisfied: setuptools>=60.9.0 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from ccxt>=1.66.32->finrl==0.3.5) (65.6.3)
# Requirement already satisfied: certifi>=2018.1.18 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from ccxt>=1.66.32->finrl==0.3.5) (2022.12.7)
# Requirement already satisfied: cryptography>=2.6.1 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from ccxt>=1.66.32->finrl==0.3.5) (3.4.8)
# Collecting aiodns>=1.1.1
#   Using cached aiodns-3.0.0-py3-none-any.whl (5.0 kB)
# Collecting cloudpickle>=1.2.0
#   Using cached cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Collecting gym-notices>=0.0.4
#   Using cached gym_notices-0.0.8-py3-none-any.whl (3.0 kB)
# Collecting protobuf!=3.19.5,>=3.15.3
#   Using cached protobuf-4.22.1-cp37-abi3-manylinux2014_x86_64.whl (302 kB)
# Collecting filelock
#   Using cached filelock-3.10.7-py3-none-any.whl (10 kB)
# Collecting grpcio>=1.32.0
#   Using cached grpcio-1.53.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.0 MB)
# Requirement already satisfied: jsonschema in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (4.17.3)
# Collecting click>=7.0
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Collecting virtualenv>=20.0.24
#   Using cached virtualenv-20.21.0-py3-none-any.whl (8.7 MB)
# Collecting tabulate
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting py-spy>=0.2.0
#   Using cached py_spy-0.3.14-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.0 MB)
# Requirement already satisfied: prometheus-client>=0.7.1 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (0.16.0)
# Collecting gpustat>=1.0.0
#   Using cached gpustat-1.0.0.tar.gz (90 kB)
#   Preparing metadata (setup.py) ... done
# Collecting aiohttp-cors
#   Using cached aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Collecting smart-open
#   Using cached smart_open-6.3.0-py3-none-any.whl (56 kB)
# Collecting colorful
#   Using cached colorful-0.5.5-py2.py3-none-any.whl (201 kB)
# Collecting opencensus
#   Using cached opencensus-0.11.2-py2.py3-none-any.whl (128 kB)
# Collecting pydantic
#   Using cached pydantic-1.10.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
# Collecting joblib>=1.1.1
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# Requirement already satisfied: scipy>=1.3.2 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from scikit-learn>=0.21.0->finrl==0.3.5) (1.10.1)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting gym>=0.17
#   Using cached gym-0.21.0.tar.gz (1.5 MB)
#   Preparing metadata (setup.py) ... done
# Collecting torch>=1.11
#   Using cached torch-2.0.0-cp38-cp38-manylinux1_x86_64.whl (619.9 MB)
# Collecting protobuf!=3.19.5,>=3.15.3
#   Using cached protobuf-3.20.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
# Requirement already satisfied: psycopg2-binary in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from wrds>=3.1.6->finrl==0.3.5) (2.9.5)
# Requirement already satisfied: sqlalchemy<2 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from wrds>=3.1.6->finrl==0.3.5) (1.4.47)
# Collecting thriftpy2>=0.3.9
#   Using cached thriftpy2-0.4.16.tar.gz (643 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from jqdatasdk->finrl==0.3.5) (1.16.0)
# Collecting pymysql>=0.7.6
#   Using cached PyMySQL-1.0.3-py3-none-any.whl (43 kB)
# Collecting pillow>=6.2.0
#   Using cached Pillow-9.4.0-cp38-cp38-manylinux_2_28_x86_64.whl (3.4 MB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.39.3-py3-none-any.whl (1.0 MB)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.0.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (300 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.4.4-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
# Collecting pyparsing>=2.3.1
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from matplotlib->finrl==0.3.5) (5.12.0)
# Requirement already satisfied: ipython>=3.2.3 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (8.11.0)
# Collecting seaborn>=0.7.1
#   Using cached seaborn-0.12.2-py3-none-any.whl (293 kB)
# Collecting empyrical>=0.5.0
#   Using cached empyrical-0.5.5.tar.gz (52 kB)
#   Preparing metadata (setup.py) ... done
# Collecting appdirs>=1.4.4
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from yfinance->finrl==0.3.5) (4.12.0)
# Collecting lxml>=4.9.1
#   Using cached lxml-4.9.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (7.1 MB)
# Collecting frozendict>=2.3.4
#   Using cached frozendict-2.3.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (112 kB)
# Collecting multitasking>=0.0.7
#   Using cached multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Collecting html5lib>=1.1
#   Using cached html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Collecting pycares>=4.0.0
#   Using cached pycares-4.3.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
# Requirement already satisfied: soupsieve>1.2 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from beautifulsoup4>=4.11.1->yfinance->finrl==0.3.5) (2.3.2.post1)
# Requirement already satisfied: cffi>=1.12 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from cryptography>=2.6.1->ccxt>=1.66.32->finrl==0.3.5) (1.15.0)
# Collecting pandas-datareader>=0.2
#   Using cached pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
# Collecting nvidia-ml-py<=11.495.46,>=11.450.129
#   Using cached nvidia_ml_py-11.495.46-py3-none-any.whl (25 kB)
# Collecting psutil>=5.6.0
#   Using cached psutil-5.9.4-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (280 kB)
# Collecting blessed>=1.17.1
#   Using cached blessed-1.20.0-py2.py3-none-any.whl (58 kB)
# Requirement already satisfied: webencodings in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from html5lib>=1.1->yfinance->finrl==0.3.5) (0.5.1)
# Requirement already satisfied: jedi>=0.16 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.18.2)
# Requirement already satisfied: pickleshare in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (3.0.38)
# Requirement already satisfied: pexpect>4.3 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (4.8.0)
# Requirement already satisfied: traitlets>=5 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (5.9.0)
# Requirement already satisfied: backcall in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (2.14.0)
# Requirement already satisfied: matplotlib-inline in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.1.6)
# Requirement already satisfied: decorator in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (5.1.1)
# Requirement already satisfied: stack-data in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.6.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from requests<3,>2->alpaca_trade_api>=2.1.0->finrl==0.3.5) (3.4)
# Requirement already satisfied: greenlet!=0.4.17 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from sqlalchemy<2->wrds>=3.1.6->finrl==0.3.5) (2.0.2)
# Collecting ply<4.0,>=3.4
#   Using cached ply-3.11-py2.py3-none-any.whl (49 kB)
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Using cached nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
# Collecting sympy
#   Using cached sympy-1.11.1-py3-none-any.whl (6.5 MB)
# Collecting nvidia-cusparse-cu11==11.7.4.91
#   Using cached nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
# Collecting nvidia-cusolver-cu11==11.4.0.1
#   Using cached nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
# Requirement already satisfied: typing-extensions in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from torch>=1.11->stable-baselines3<2.0.0,>=1.6.2->finrl==0.3.5) (4.5.0)
# Requirement already satisfied: jinja2 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from torch>=1.11->stable-baselines3<2.0.0,>=1.6.2->finrl==0.3.5) (3.1.2)
# Collecting nvidia-nccl-cu11==2.14.3
#   Using cached nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Using cached nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Using cached nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Using cached nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
# Collecting nvidia-curand-cu11==10.2.10.91
#   Using cached nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
# Collecting networkx
#   Using cached networkx-3.0-py3-none-any.whl (2.0 MB)
# Collecting nvidia-nvtx-cu11==11.7.91
#   Using cached nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
# Collecting nvidia-cuda-cupti-cu11==11.7.101
#   Using cached nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
# Collecting triton==2.0.0
#   Using cached triton-2.0.0-1-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.2 MB)
# Collecting nvidia-cufft-cu11==10.9.0.58
#   Using cached nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
# Requirement already satisfied: wheel in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.11->stable-baselines3<2.0.0,>=1.6.2->finrl==0.3.5) (0.38.4)
# Collecting lit
#   Downloading lit-16.0.0.tar.gz (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.0/145.0 kB 835.2 kB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting cmake
#   Downloading cmake-3.26.1-py2.py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (24.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 21.8 MB/s eta 0:00:0000:0100:01
# Collecting distlib<1,>=0.3.6
#   Using cached distlib-0.3.6-py2.py3-none-any.whl (468 kB)
# Requirement already satisfied: platformdirs<4,>=2.4 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from virtualenv>=20.0.24->ray[default,tune]>=2.0.0->finrl==0.3.5) (3.2.0)
# Collecting gym[box2d]
#   Using cached gym-0.26.1.tar.gz (719 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Using cached gym-0.26.0.tar.gz (710 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Using cached gym-0.25.2.tar.gz (734 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Using cached gym-0.25.1.tar.gz (732 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Using cached gym-0.25.0.tar.gz (720 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Using cached gym-0.24.1.tar.gz (696 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Using cached gym-0.24.0.tar.gz (694 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Using cached gym-0.23.1.tar.gz (626 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Using cached gym-0.23.0.tar.gz (624 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Using cached gym-0.22.0.tar.gz (631 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting box2d-py==2.3.5
#   Using cached box2d-py-2.3.5.tar.gz (374 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pyglet>=1.4.0
#   Downloading pyglet-2.0.5-py3-none-any.whl (831 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 831.3/831.3 kB 23.4 MB/s eta 0:00:0000:01
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from jsonschema->ray[default,tune]>=2.0.0->finrl==0.3.5) (0.18.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from jsonschema->ray[default,tune]>=2.0.0->finrl==0.3.5) (1.3.10)
# Collecting opencensus-context>=0.1.3
#   Using cached opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Collecting google-api-core<3.0.0,>=1.0.0
#   Using cached google_api_core-2.11.0-py3-none-any.whl (120 kB)
# Requirement already satisfied: wcwidth>=0.1.4 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from blessed>=1.17.1->gpustat>=1.0.0->ray[default,tune]>=2.0.0->finrl==0.3.5) (0.2.6)
# Requirement already satisfied: pycparser in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt>=1.66.32->finrl==0.3.5) (2.21)
# Collecting google-auth<3.0dev,>=2.14.1
#   Downloading google_auth-2.17.0-py2.py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.1/178.1 kB 16.3 MB/s eta 0:00:00
# Collecting googleapis-common-protos<2.0dev,>=1.56.2
#   Downloading googleapis_common_protos-1.59.0-py2.py3-none-any.whl (223 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.6/223.6 kB 17.8 MB/s eta 0:00:00
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from pexpect>4.3->ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.7.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from jinja2->torch>=1.11->stable-baselines3<2.0.0,>=1.6.2->finrl==0.3.5) (2.1.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from stack-data->ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (2.2.1)
# Requirement already satisfied: pure-eval in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from stack-data->ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages (from stack-data->ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (1.2.0)
# Collecting mpmath>=0.19
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 20.2 MB/s eta 0:00:00
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Building wheels for collected packages: finrl, exchange_calendars, gym, elegantrl, gputil, pyfolio, empyrical, gpustat, thriftpy2, box2d-py, lit
#   Building wheel for finrl (pyproject.toml) ... done
#   Created wheel for finrl: filename=finrl-0.3.5-py3-none-any.whl size=4668526 sha256=f55b41d967223f3a27e4404f4d382736d5c5cbc2e1cfd7736de48586998df184
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qbjr6b_h/wheels/40/83/3b/1fdae3cf52844e165828ceb467518b7a110a263cbd6a2282be
#   Building wheel for exchange_calendars (setup.py) ... done
#   Created wheel for exchange_calendars: filename=exchange_calendars-3.6.3-py3-none-any.whl size=182619 sha256=31ead489290e46f4c81c172b0615a3074d83b0cffe9d4a8da9ddd0b0a9188deb
#   Stored in directory: /home/ga_aiot/.cache/pip/wheels/b7/5a/70/69aa223926486d0dee4ff7949dba488e671db1bef9e14040e7
#   Building wheel for gym (setup.py) ... done
#   Created wheel for gym: filename=gym-0.21.0-py3-none-any.whl size=1616798 sha256=fea5110af2479816057643cabe970f4122223e02d8ee0db8268452877ddbb759
#   Stored in directory: /home/ga_aiot/.cache/pip/wheels/27/6d/b3/a3a6e10704795c9b9000f1ab2dc480dfe7bed42f5972806e73
#   Building wheel for elegantrl (setup.py) ... done
#   Created wheel for elegantrl: filename=elegantrl-0.3.6-py3-none-any.whl size=195041 sha256=53451a72a0b90b905b58090215ab887408cc928ea3f1d8c06bcede750be0b529
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qbjr6b_h/wheels/d6/fb/88/7d5e5490b35f78191267fee312ce81baac55c6b9d89151e72a
#   Building wheel for gputil (setup.py) ... done
#   Created wheel for gputil: filename=GPUtil-1.4.0-py3-none-any.whl size=7392 sha256=bf59a20c84b22c2d2277b3f510e302e8d181bd30ca6a8de1e18511f43fdd125b
#   Stored in directory: /home/ga_aiot/.cache/pip/wheels/ba/03/bb/7a97840eb54479b328672e15a536e49dc60da200fb21564d53
#   Building wheel for pyfolio (setup.py) ... done
#   Created wheel for pyfolio: filename=pyfolio-0.9.2+75.g4b901f6-py3-none-any.whl size=75760 sha256=d3baf8d2add09ece93ef77bfcd0cc7cf8ccfa706ce3b58ddfe33f6140d8f0bee
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qbjr6b_h/wheels/7b/59/8b/3c276a18b58c04a1fd0e1351e979fb5396f93fbde5b5438df1
#   Building wheel for empyrical (setup.py) ... done
#   Created wheel for empyrical: filename=empyrical-0.5.5-py3-none-any.whl size=39764 sha256=e0f4971fd01728bd2ab8c9d0cb6f91027fc16dc300c767bc349e6591252c932e
#   Stored in directory: /home/ga_aiot/.cache/pip/wheels/0d/68/bb/926065fb744e7d7cb67334cb1a9c696722abc8303e5dc9a8d0
#   Building wheel for gpustat (setup.py) ... done
#   Created wheel for gpustat: filename=gpustat-1.0.0-py3-none-any.whl size=19867 sha256=b1846212da456f822e5ce652bb26fb77dfef61e1baaa8c9bc950bd084769a595
#   Stored in directory: /home/ga_aiot/.cache/pip/wheels/1b/ed/14/0d513c962b25da841c42022cb5847c2ef835902c8563b8fb01
#   Building wheel for thriftpy2 (setup.py) ... done
#   Created wheel for thriftpy2: filename=thriftpy2-0.4.16-cp38-cp38-linux_x86_64.whl size=1262339 sha256=60de51deff56a2a1223d75c0a0202cb59f033665b33a36b8bf53273c657c2c71
#   Stored in directory: /home/ga_aiot/.cache/pip/wheels/a2/62/fd/0862bb8a1775cdea40a14af28ae2b490c9c32555df3361f590
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp38-cp38-linux_x86_64.whl size=3117638 sha256=45d7b5357a433be10885df30eba9aaaca6e0bd64e098dcdf9bc2485c22a099a4
#   Stored in directory: /home/ga_aiot/.cache/pip/wheels/8b/95/16/1dc99ff9a3f316ff245fdb5c9086cd13c35dad630809909075
#   Building wheel for lit (setup.py) ... done
#   Created wheel for lit: filename=lit-16.0.0-py3-none-any.whl size=93582 sha256=79075edc1914357e0249526e7c140af64b8171501ba0b642cf2a5dad6604c748
#   Stored in directory: /home/ga_aiot/.cache/pip/wheels/30/c8/c0/9d24f63f30f4879b8efb718a11b2191ef5c8510259d1d6c392
# Successfully built finrl exchange_calendars gym elegantrl gputil pyfolio empyrical gpustat thriftpy2 box2d-py lit
# Installing collected packages: pyglet, pyasn1, py-spy, ply, opencensus-context, nvidia-ml-py, multitasking, msgpack, mpmath, lit, korean_lunar_calendar, gputil, distlib, colorful, cmake, box2d-py, appdirs, websockets, toolz, thriftpy2, threadpoolctl, tabulate, sympy, smart-open, rsa, PyYAML, pyparsing, pymysql, pyluach, pydantic, pyasn1-modules, psutil, protobuf, pillow, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, networkx, multidict, lz4, lxml, kiwisolver, joblib, importlib-metadata, html5lib, grpcio, frozenlist, frozendict, fonttools, filelock, deprecation, cycler, contourpy, cloudpickle, click, cachetools, blessed, async-timeout, yarl, virtualenv, tensorboardX, scikit-learn, pycares, nvidia-cusolver-cu11, nvidia-cudnn-cu11, matplotlib, gym, gpustat, googleapis-common-protos, google-auth, aiosignal, yfinance, stockstats, seaborn, ray, pandas-datareader, jqdatasdk, google-api-core, exchange_calendars, aiohttp, aiodns, opencensus, empyrical, ccxt, alpaca_trade_api, aiohttp-cors, pyfolio, triton, torch, stable-baselines3, elegantrl, finrl
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 6.1.0
#     Uninstalling importlib-metadata-6.1.0:
#       Successfully uninstalled importlib-metadata-6.1.0
# Successfully installed PyYAML-6.0 aiodns-3.0.0 aiohttp-3.8.1 aiohttp-cors-0.7.0 aiosignal-1.3.1 alpaca_trade_api-3.0.0 appdirs-1.4.4 async-timeout-4.0.2 blessed-1.20.0 box2d-py-2.3.5 cachetools-5.3.0 ccxt-3.0.44 click-8.1.3 cloudpickle-2.2.1 cmake-3.26.1 colorful-0.5.5 contourpy-1.0.7 cycler-0.11.0 deprecation-2.1.0 distlib-0.3.6 elegantrl-0.3.6 empyrical-0.5.5 exchange_calendars-3.6.3 filelock-3.10.7 finrl-0.3.5 fonttools-4.39.3 frozendict-2.3.6 frozenlist-1.3.3 google-api-core-2.11.0 google-auth-2.17.0 googleapis-common-protos-1.59.0 gpustat-1.0.0 gputil-1.4.0 grpcio-1.53.0 gym-0.21.0 html5lib-1.1 importlib-metadata-4.13.0 joblib-1.2.0 jqdatasdk-1.8.11 kiwisolver-1.4.4 korean_lunar_calendar-0.3.1 lit-16.0.0 lxml-4.9.2 lz4-4.3.2 matplotlib-3.7.1 mpmath-1.3.0 msgpack-1.0.3 multidict-6.0.4 multitasking-0.0.11 networkx-3.0 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-ml-py-11.495.46 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 opencensus-0.11.2 opencensus-context-0.1.3 pandas-datareader-0.10.0 pillow-9.4.0 ply-3.11 protobuf-3.20.3 psutil-5.9.4 py-spy-0.3.14 pyasn1-0.4.8 pyasn1-modules-0.2.8 pycares-4.3.0 pydantic-1.10.7 pyfolio-0.9.2+75.g4b901f6 pyglet-2.0.5 pyluach-2.2.0 pymysql-1.0.3 pyparsing-3.0.9 ray-2.3.1 rsa-4.9 scikit-learn-1.2.2 seaborn-0.12.2 smart-open-6.3.0 stable-baselines3-1.7.0 stockstats-0.5.2 sympy-1.11.1 tabulate-0.9.0 tensorboardX-2.6 threadpoolctl-3.1.0 thriftpy2-0.4.16 toolz-0.12.0 torch-2.0.0 triton-2.0.0 virtualenv-20.21.0 websockets-10.4 yarl-1.8.2 yfinance-0.2.14

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. A list of Python packages
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from stable_baselines3.common.logger import configure
from finrl.meta.data_processor import DataProcessor

from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline
from pprint import pprint

import sys
sys.path.append("../FinRL")

import itertools
# Out:
# /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages/pyfolio/pos.py:26: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
from finrl import config
from finrl import config_tickers
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)
check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance provides stock data, financial news, financial reports, etc. Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** in FinRL-Meta to fetch data via Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()

# %%
# from config.py, TRAIN_START_DATE is a string
TRAIN_START_DATE
# from config.py, TRAIN_END_DATE is a string
TRAIN_END_DATE
# Out:
# '2020-07-31'

# %%
TRAIN_START_DATE = '2009-01-01'
TRAIN_END_DATE = '2020-07-01'
TRADE_START_DATE = '2020-07-01'
TRADE_END_DATE = '2021-10-31'

# %%
df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TRADE_END_DATE,
                     ticker_list = config_tickers.DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (94331, 8)

# %%
print(config_tickers.DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
df.shape
# Out:
# (94331, 8)

# %%
df.sort_values(['date','tic'],ignore_index=True).head()
# Out:
#          date       open       high        low      close     volume   tic  \
# 0  2009-01-02   3.067143   3.251429   3.041429   2.758535  746015200  AAPL
# 1  2009-01-02  58.590000  59.080002  57.750000  43.832649    6547900  AMGN
# 2  2009-01-02  18.570000  19.520000  18.400000  15.365304   10955700   AXP
# 3  2009-01-02  42.799999  45.560001  42.779999  33.941093    7010200    BA
# 4  2009-01-02  44.910000  46.980000  44.709999  31.579346    7117200   CAT
#
#    day
# 0    4
# 1    4
# 2    4
# 3    4
# 4    4

# %% [markdown]
# # Part 4: Preprocess Data
# We need to check for missing data and do feature engineering to convert the data point into a state.
# * **Adding technical indicators**. In practical trading, various information needs to be taken into account, such as historical prices, current holding shares, technical indicators, etc. Here, we demonstrate two trend-following technical indicators: MACD and RSI.
# * **Adding turbulence index**. Risk-aversion reflects whether an investor prefers to protect the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the turbulence index that measures extreme fluctuation of asset price.

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    tech_indicator_list = INDICATORS,
                    use_vix=True,
                    use_turbulence=True,
                    user_defined_feature = False)

processed = fe.preprocess_data(df)
# Out:
# Successfully added technical indicators
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (3229, 8)
# Successfully added vix
# Successfully added turbulence index

# %%
list_ticker = processed["tic"].unique().tolist()
list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str))
combination = list(itertools.product(list_date,list_ticker))

processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")
processed_full = processed_full[processed_full['date'].isin(processed['date'])]
processed_full = processed_full.sort_values(['date','tic'])

processed_full = processed_full.fillna(0)

# %%
processed_full.sort_values(['date','tic'],ignore_index=True).head(10)
# Out:
#          date   tic       open       high        low      close       volume  \
# 0  2009-01-02  AAPL   3.067143   3.251429   3.041429   2.758535  746015200.0
# 1  2009-01-02  AMGN  58.590000  59.080002  57.750000  43.832649    6547900.0
# 2  2009-01-02   AXP  18.570000  19.520000  18.400000  15.365304   10955700.0
# 3  2009-01-02    BA  42.799999  45.560001  42.779999  33.941093    7010200.0
# 4  2009-01-02   CAT  44.910000  46.980000  44.709999  31.579346    7117200.0
# 5  2009-01-02   CRM   8.025000   8.550000   7.912500   8.505000    4069200.0
# 6  2009-01-02  CSCO  16.410000  17.000000  16.250000  11.948336   40980600.0
# 7  2009-01-02   CVX  74.230003  77.300003  73.580002  43.677189   13695900.0
# 8  2009-01-02   DIS  22.760000  24.030001  22.500000  20.597496    9796600.0
# 9  2009-01-02    GS  84.019997  87.620003  82.190002  69.251747   14088500.0
#
#    day  macd  boll_ub   boll_lb  rsi_30     cci_30  dx_30  close_30_sma  \
# 0  4.0   0.0  2.98139  2.652101   100.0  66.666667  100.0      2.758535
# 1  4.0   0.0  2.98139  2.652101   100.0  66.666667  100.0     43.832649
# 2  4.0   0.0  2.98139  2.652101   100.0  66.666667  100.0     15.365304
# 3  4.0   0.0  2.98139  2.652101   100.0  66.666667  100.0     33.941093
# 4  4.0   0.0  2.98139  2.652101   100.0  66.666667  100.0     31.579346
# 5  4.0   0.0  2.98139  2.652101   100.0  66.666667  100.0      8.505000
# 6  4.0   0.0  2.98139  2.652101   100.0  66.666667  100.0     11.948336
# 7  4.0   0.0  2.98139  2.652101   100.0  66.666667  100.0     43.677189
# 8  4.0   0.0  2.98139  2.652101   100.0  66.666667  100.0     20.597496
# 9  4.0   0.0  2.98139  2.652101   100.0  66.666667  100.0     69.251747
#
#    close_60_sma        vix  turbulence
# 0      2.758535  39.189999         0.0
# 1     43.832649  39.189999         0.0
# 2     15.365304  39.189999         0.0
# 3     33.941093  39.189999         0.0
# 4     31.579346  39.189999         0.0
# 5      8.505000  39.189999         0.0
# 6     11.948336  39.189999         0.0
# 7     43.677189  39.189999         0.0
# 8     20.597496  39.189999         0.0
# 9     69.251747  39.189999         0.0

# %%
mvo_df = processed_full.sort_values(['date','tic'],ignore_index=True)[['date','tic','close']]

# %%
import pickle
processed_full.to_pickle('datasets/processed.pkl')

# %% [markdown]
# <a id='4'></a>
# # Part 5. Build A Market Environment in OpenAI Gym-style
# The training process involves observing stock price change, taking an action and reward's calculation. By interacting with the market environment, the agent will eventually derive a trading strategy that may maximize (expected) rewards.
#
# Our market environment, based on OpenAI Gym, simulates stock markets with historical market data.

# %% [markdown]
# ## Data Split
# We split the data into training set and testing set as follows:
#
# Training data period: 2009-01-01 to 2020-07-01
#
# Trading data period: 2020-07-01 to 2021-10-31

# %%
train = data_split(processed_full, TRAIN_START_DATE,TRAIN_END_DATE)
trade = data_split(processed_full, TRADE_START_DATE,TRADE_END_DATE)
print(len(train))
print(len(trade))
# Out:
# 83897
# 9744

# %%
train.tail()
# Out:
#             date  tic        open        high         low       close  \
# 2892  2020-06-30  UNH  288.570007  296.450012  287.660004  283.967346
# 2892  2020-06-30    V  191.490005  193.750000  190.160004  189.604019
# 2892  2020-06-30   VZ   54.919998   55.290001   54.360001   48.169010
# 2892  2020-06-30  WBA   42.119999   42.580002   41.759998   37.630478
# 2892  2020-06-30  WMT  119.220001  120.129997  118.540001  114.713837
#
#           volume  day      macd     boll_ub     boll_lb     rsi_30     cci_30  \
# 2892   2932900.0  1.0 -0.019216  299.902630  267.660553  52.413051 -25.942568
# 2892   9040100.0  1.0  1.042555  197.569696  183.942010  53.021038 -51.608216
# 2892  17414800.0  1.0 -0.417955   51.555482   46.593789  48.097038 -51.186702
# 2892   4782100.0  1.0 -0.080963   41.075409   35.173592  48.830177 -14.613242
# 2892   6836400.0  1.0 -0.875819  118.025182  112.134176  48.159676 -69.977800
#
#          dx_30  close_30_sma  close_60_sma    vix  turbulence
# 2892  1.846804    284.207998    277.281663  30.43   12.918722
# 2892  2.013358    190.347371    180.598284  30.43   12.918722
# 2892  8.508886     48.776546     49.209270  30.43   12.918722
# 2892  1.500723     37.726357     37.533499  30.43   12.918722
# 2892  3.847271    116.359491    118.271671  30.43   12.918722

# %%
trade.head()
# Out:
#          date   tic        open        high         low       close  \
# 0  2020-07-01  AAPL   91.279999   91.839996   90.977501   89.494568
# 0  2020-07-01  AMGN  235.520004  256.230011  232.580002  234.614319
# 0  2020-07-01   AXP   95.250000   96.959999   93.639999   91.078468
# 0  2020-07-01    BA  185.880005  190.610001  180.039993  180.320007
# 0  2020-07-01   CAT  129.380005  129.399994  125.879997  118.455795
#
#         volume  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 0  110737200.0  2.0  3.000855   92.276535   79.814267  62.807167  107.499082
# 0    6575800.0  2.0  3.552510  227.036704  195.594640  61.279637  270.849168
# 0    3301000.0  2.0 -0.384903  109.215320   86.798778  48.504818  -66.306156
# 0   49036700.0  2.0  5.443193  220.721139  160.932863  50.925771   24.220608
# 0    2807800.0  2.0  1.249468  128.246934  111.290115  52.865423   35.692974
#
#        dx_30  close_30_sma  close_60_sma        vix  turbulence
# 0  29.730532     83.550963     77.363087  28.620001   53.068023
# 0  46.806139    209.902521    210.950773  28.620001   53.068023
# 0   3.142448     96.180265     89.702836  28.620001   53.068023
# 0  15.932920    176.472335    155.614168  28.620001   53.068023
# 0  14.457404    117.239538    111.578320  28.620001   53.068023

# %%
INDICATORS
# Out:
# ['macd',
#  'boll_ub',
#  'boll_lb',
#  'rsi_30',
#  'cci_30',
#  'dx_30',
#  'close_30_sma',
#  'close_60_sma']

# %%
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 291

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}


e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# %% [markdown]
# ## Environment for Training

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# <a id='5'></a>
# # Part 6: Train DRL Agents
# * The DRL algorithms are from **Stable Baselines 3**. Users are also encouraged to try **ElegantRL** and **Ray RLlib**.
# * FinRL includes fine-tuned standard DRL algorithms, such as DQN, DDPG, Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.

# %%
agent = DRLAgent(env = env_train)

if_using_a2c = False
if_using_ddpg = False
if_using_ppo = True
if_using_td3 = False
if_using_sac = False

# %% [markdown]
# ### Agent Training: 5 algorithms (A2C, DDPG, PPO, TD3, SAC)

# %% [markdown]
# ### Agent 1: A2C

# %%
agent = DRLAgent(env = env_train)
model_a2c = agent.get_model("a2c")

if if_using_a2c:
  # set up logger
  tmp_path = RESULTS_DIR + '/a2c'
  new_logger_a2c = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_a2c.set_logger(new_logger_a2c)
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cuda device

# %%
trained_a2c = agent.train_model(model=model_a2c, 
                             tb_log_name='a2c',
                             total_timesteps=50000) if if_using_a2c else None

# %% [markdown]
# ### Agent 2: DDPG

# %%
agent = DRLAgent(env = env_train)
model_ddpg = agent.get_model("ddpg")

if if_using_ddpg:
  # set up logger
  tmp_path = RESULTS_DIR + '/ddpg'
  new_logger_ddpg = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ddpg.set_logger(new_logger_ddpg)
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cuda device

# %%
trained_ddpg = agent.train_model(model=model_ddpg, 
                             tb_log_name='ddpg',
                             total_timesteps=50000) if if_using_ddpg else None

# %% [markdown]
# ### Agent 3: PPO

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)

if if_using_ppo:
  # set up logger
  tmp_path = RESULTS_DIR + '/ppo'
  new_logger_ppo = configure(tmp_path, ["stdout", "csv"])
  # Set new logger
  model_ppo.set_logger(new_logger_ppo)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to results/ppo

# %%
trained_ppo = agent.train_model(model=model_ppo, 
                             tb_log_name='ppo',
                             total_timesteps=50000) if if_using_ppo else None
# Out:
# -----------------------------------
# | time/              |            |
# |    fps             | 123        |
# |    iterations      | 1          |
# |    time_elapsed    | 16         |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.87409246 |
# -----------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 121        |
# |    iterations           | 2          |
# |    time_elapsed         | 33         |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.01408047 |
# |    clip_fraction        | 0.22       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.2      |
# |    explained_variance   | -0.00917   |
# |    learning_rate        | 0.00025    |
# |    loss                 | 5.32       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.026     |
# |    reward               | 1.2165499  |
# |    std                  | 1          |
# |    value_loss           | 12.6       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 3          |
# |    time_elapsed         | 51         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01373083 |
# |    clip_fraction        | 0.138      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.2      |
# |    explained_variance   | -0.0006    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 30.9       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0198    |
# |    reward               | -1.0839758 |
# |    std                  | 1          |
# |    value_loss           | 53.5       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 118          |
# |    iterations           | 4            |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0142460205 |
# |    clip_fraction        | 0.121        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -41.3        |
# |    explained_variance   | -0.0107      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 34.1         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0199      |
# |    reward               | 4.4024525    |
# |    std                  | 1            |
# |    value_loss           | 79.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 5           |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.020084038 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.0276     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 5.91        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0234     |
# |    reward               | 3.0177271   |
# |    std                  | 1.01        |
# |    value_loss           | 14.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 6           |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.024680343 |
# |    clip_fraction        | 0.266       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.00784    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 11.1        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0167     |
# |    reward               | 2.265975    |
# |    std                  | 1.01        |
# |    value_loss           | 45.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 7           |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.015252027 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | -0.0106     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 35          |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00967    |
# |    reward               | 1.5387884   |
# |    std                  | 1.01        |
# |    value_loss           | 73.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 8           |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.020713825 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | 0.000518    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 16          |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0185     |
# |    reward               | 0.914193    |
# |    std                  | 1.01        |
# |    value_loss           | 32.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 9           |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.023235459 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.5       |
# |    explained_variance   | -0.00427    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 48.9        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0161     |
# |    reward               | 1.1484674   |
# |    std                  | 1.01        |
# |    value_loss           | 54.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 10          |
# |    time_elapsed         | 172         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.027101006 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.6       |
# |    explained_variance   | -0.0043     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 32.7        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0191     |
# |    reward               | 0.51587915  |
# |    std                  | 1.01        |
# |    value_loss           | 50.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 11          |
# |    time_elapsed         | 189         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.019946411 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.6       |
# |    explained_variance   | -0.00497    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 79.3        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0167     |
# |    reward               | 0.7673922   |
# |    std                  | 1.02        |
# |    value_loss           | 101         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 118          |
# |    iterations           | 12           |
# |    time_elapsed         | 206          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.024436116  |
# |    clip_fraction        | 0.247        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -41.6        |
# |    explained_variance   | -0.0272      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 13.9         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.017       |
# |    reward               | -0.040019765 |
# |    std                  | 1.02         |
# |    value_loss           | 22.3         |
# ------------------------------------------
# day: 2892, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 4113645.85
# total_reward: 3113645.85
# total_cost: 308508.52
# total_trades: 77965
# Sharpe: 0.782
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 13          |
# |    time_elapsed         | 223         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.016569972 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.7       |
# |    explained_variance   | 0.0057      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 68.5        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.014      |
# |    reward               | 0.24337457  |
# |    std                  | 1.02        |
# |    value_loss           | 119         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 14          |
# |    time_elapsed         | 241         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.021256497 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.7       |
# |    explained_variance   | -0.00259    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 46.5        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0162     |
# |    reward               | -2.0361376  |
# |    std                  | 1.02        |
# |    value_loss           | 88.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 15          |
# |    time_elapsed         | 258         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.017377535 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | -0.00338    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 21.7        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0156     |
# |    reward               | 3.4273121   |
# |    std                  | 1.02        |
# |    value_loss           | 40.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 16          |
# |    time_elapsed         | 276         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.028923258 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | -0.00078    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 39.6        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0156     |
# |    reward               | -0.19818015 |
# |    std                  | 1.02        |
# |    value_loss           | 73.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 17          |
# |    time_elapsed         | 294         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.022991568 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | -0.00882    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 45.2        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0119     |
# |    reward               | 0.87593013  |
# |    std                  | 1.03        |
# |    value_loss           | 115         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 18          |
# |    time_elapsed         | 311         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.015634002 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.9       |
# |    explained_variance   | 0.00852     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 58.3        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.016      |
# |    reward               | -0.38031265 |
# |    std                  | 1.03        |
# |    value_loss           | 91          |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 118        |
# |    iterations           | 19         |
# |    time_elapsed         | 329        |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.01792189 |
# |    clip_fraction        | 0.174      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.9      |
# |    explained_variance   | -0.0415    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 8.61       |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0164    |
# |    reward               | -1.234743  |
# |    std                  | 1.03       |
# |    value_loss           | 20.2       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 20          |
# |    time_elapsed         | 346         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.020456713 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42         |
# |    explained_variance   | 0.00639     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 62.7        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0127     |
# |    reward               | -0.5306661  |
# |    std                  | 1.03        |
# |    value_loss           | 156         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 21          |
# |    time_elapsed         | 364         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.016757607 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42         |
# |    explained_variance   | -0.00981    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 73.7        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00924    |
# |    reward               | -10.989283  |
# |    std                  | 1.03        |
# |    value_loss           | 241         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 22          |
# |    time_elapsed         | 381         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.021406684 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42         |
# |    explained_variance   | 0.0215      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 19.8        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.021      |
# |    reward               | 3.810764    |
# |    std                  | 1.03        |
# |    value_loss           | 58.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 23          |
# |    time_elapsed         | 400         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.031623352 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.1       |
# |    explained_variance   | -0.00627    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 52.4        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0137     |
# |    reward               | -0.34628332 |
# |    std                  | 1.03        |
# |    value_loss           | 145         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 24          |
# |    time_elapsed         | 418         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.028607458 |
# |    clip_fraction        | 0.266       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.1       |
# |    explained_variance   | 0.00388     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 164         |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.019      |
# |    reward               | 5.115101    |
# |    std                  | 1.03        |
# |    value_loss           | 193         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 25          |
# |    time_elapsed         | 436         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.015377594 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.2       |
# |    explained_variance   | -0.00896    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 108         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0145     |
# |    reward               | 0.58969903  |
# |    std                  | 1.04        |
# |    value_loss           | 167         |
# -----------------------------------------

# %%
trained_ppo.save('trained_ppo_model')

# %% [markdown]
# ### Agent 4: TD3

# %%
agent = DRLAgent(env = env_train)
TD3_PARAMS = {"batch_size": 100, 
              "buffer_size": 1000000, 
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)

if if_using_td3:
  # set up logger
  tmp_path = RESULTS_DIR + '/td3'
  new_logger_td3 = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_td3.set_logger(new_logger_td3)

# %%
trained_td3 = agent.train_model(model=model_td3, 
                             tb_log_name='td3',
                             total_timesteps=50000) if if_using_td3 else None

# %% [markdown]
# ### Agent 5: SAC

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.0001,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)

if if_using_sac:
  # set up logger
  tmp_path = RESULTS_DIR + '/sac'
  new_logger_sac = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_sac.set_logger(new_logger_sac)

# %%
trained_sac = agent.train_model(model=model_sac, 
                             tb_log_name='sac',
                             total_timesteps=50000) if if_using_sac else None

# %% [markdown]
# ## In-sample Performance
#
# Assume that the initial capital is $1,000,000.

# %% [markdown]
# ### Set turbulence threshold
# Set the turbulence threshold to be greater than the maximum of insample turbulence data. If current turbulence index is greater than the threshold, then we assume that the current market is volatile

# %%
data_risk_indicator = processed_full[(processed_full.date<TRAIN_END_DATE) & (processed_full.date>=TRAIN_START_DATE)]
insample_risk_indicator = data_risk_indicator.drop_duplicates(subset=['date'])

# %%
insample_risk_indicator.vix.describe()

# %%
insample_risk_indicator.vix.quantile(0.996)

# %%
insample_risk_indicator.turbulence.describe()

# %%
insample_risk_indicator.turbulence.quantile(0.996)

# %% [markdown]
# ### Trading (Out-of-sample Performance)
#
# We update periodically in order to take full advantage of the data, e.g., retrain quarterly, monthly or weekly. We also tune the parameters along the way, in this notebook we use the in-sample data from 2009-01 to 2020-07 to tune the parameters once, so there is some alpha decay here as the length of trade date extends.
#
# Numerous hyperparameters – e.g. the learning rate, the total number of samples to train on – influence the learning process and are usually determined by testing some variations.

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from stable_baselines3.common.logger import configure
from finrl.meta.data_processor import DataProcessor

from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline
from pprint import pprint

import sys
sys.path.append("../FinRL")
import itertools
# Out:
# /home/ga_aiot/anaconda3/envs/finrl2/lib/python3.8/site-packages/pyfolio/pos.py:26: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(

# %%
from finrl import config
from finrl import config_tickers
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

# %%
##Initialize with model loading. . . 
from stable_baselines3 import PPO
trained_ppo = PPO.load('trained_ppo_model')

# %%
import pickle 
with open('datasets/processed.pkl', 'rb') as f:
    processed_full = pickle.load(f)
TRADE_START_DATE = '2020-07-01'
TRADE_END_DATE = '2021-10-28'
trade = data_split(processed_full, TRADE_START_DATE,TRADE_END_DATE)

# %%
stock_dimension = len(trade.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}
# Out:
# Stock Dimension: 29, State Space: 291

# %%
#Load ppo weights; 
from stable_baselines3 import PPO
trained_ppo = PPO.load('trained_ppo_model')
e_trade_gym = StockTradingEnv(df = trade, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs)
# env_trade, obs_trade = e_trade_gym.get_sb_env()

# %%
trained_model = trained_ppo
df_account_value_ppo, df_actions_ppo = DRLAgent.DRL_prediction(
    model=trained_model, 
    environment = e_trade_gym)
# Out:
# hit end!

# %%
df_actions_ppo.tail(10)
# Out:
#             AAPL  AMGN  AXP  BA  CAT  CRM  CSCO  CVX  DIS  GS  ...  MRK  MSFT  \
# date                                                           ...
# 2021-10-13     0     0    0   0    0    0     0    0    0  -6  ...    0     0
# 2021-10-14     0     0    0   0    0    0     0    0    0  -6  ...    0     0
# 2021-10-15     0     0    0   0    0    0     0    0    0  -6  ...    0     0
# 2021-10-18     0     0    0   0    0    0     0    0    0  -6  ...    0     0
# 2021-10-19     0     0    0   0    0    0     0    0    0  -6  ...    0     0
# 2021-10-20     1     0    0   0    1    0     0    0    0  -7  ...    0     0
# 2021-10-21     0     0    0  -2    7    0     0    0    0 -10  ...    0     0
# 2021-10-22     0     2    0   0    0    0     0    0    0  -9  ...    0    -1
# 2021-10-25     0     0    0  -1    0    0     0    0    0  -5  ...    0     0
# 2021-10-26     0     0    0  -1    0    0     0    0    0  -5  ...    0     0
#
#             NKE  PG  TRV  UNH  V  VZ  WBA  WMT
# date
# 2021-10-13    0   0    0    0  0   1    0    0
# 2021-10-14    0   0    0    0  0   0    0    0
# 2021-10-15    0   0    0    0  0   0    0    0
# 2021-10-18    0   0    0    0  0   0    0    0
# 2021-10-19    0   0    0    0  0   1    0    0
# 2021-10-20    0   0    0    0  0   0    0    0
# 2021-10-21    0   0    0    0  0   0    0    0
# 2021-10-22    0   0    0    0  0   0    0    0
# 2021-10-25    0   0    0    0  0   0    0    0
# 2021-10-26    0   0    0    0  0   0    0    0
#
# [10 rows x 29 columns]

# %%
#Added NAV display over assets.
holdings = df_actions_ppo.sum()
holdings.index.name = 'tic'
holdings = holdings.reset_index()
holdings = holdings.rename(columns={0: 'shares'})
last_date = trade.iloc[-1]['date']
df_last_date = trade[trade['date'] == last_date]
merged_df = pd.merge(df_last_date, holdings, on='tic')
merged_df['NAV'] = merged_df['shares']*merged_df['close']
merged_df['NAV'].sum()
# Out:
# 1311217.3968658447

# %%
df_account_value_ppo.tail(1)
# Out:
#            date  account_value
# 334  2021-10-27   1.311220e+06

# %%
def inference(df,tsd,ted):
    trade = data_split(df, tsd,ted)
    e_trade_gym = StockTradingEnv(df = trade, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs)
    trained_model = trained_ppo
    acc_value, actions = DRLAgent.DRL_prediction(model=trained_model, environment = e_trade_gym)
    return actions
df_trade = inference(processed_full,'2020-07-01','2021-10-21')
df_trade.tail(1)
